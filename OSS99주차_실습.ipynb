# %%
class Foo:
  def __getitem__(self,pos):
    return range(0,30,10)[pos]

# %%
f[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2714457172.py in <cell line: 0>()
# ----> 1 f[1]
#       2 f = Foo()
#
# NameError: name 'f' is not defined

# %%
f = Foo()

for i in f:
    print(i)
# Out:
# 0
# 10
# 20

# %%
20 in f
# Out:
# True

# %%
15 in f
# Out:
# False

# %%
from random import shuffle
import collections

Card = collections.namedtuple('Card', ['rank', 'suit'])

class FrenchDeck:
    ranks = [str(n) for n in range(2, 11)] + list('JQKA')
    suits = 'spades diamonds clubs hearts'.split()

    def __init__(self):
        self._cards = [Card(rank, suit) for suit in self.suits
                                       for rank in self.ranks]

    def __len__(self):
        return len(self._cards)

    def __getitem__(self, position):
        return self._cards[position]

# %%
from random import shuffle
from frenchdeck import FrenchDeck
deck = FrenchDeck()
shuffle(deck)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4017966551.py in <cell line: 0>()
#       1 from random import shuffle
# ----> 2 from frenchdeck import FrenchDeck
#       3 deck = FrenchDeck()
#       4 shuffle(deck)
#
# ModuleNotFoundError: No module named 'frenchdeck'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def set_card(deck, position, card):
    deck._cards[position] = card

# %%
FrenchDeck.__setitem__ = set_card
shuffle(deck)
deck[:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1264088638.py in <cell line: 0>()
#       1 FrenchDeck.__setitem__ = set_card
# ----> 2 shuffle(deck)
#       3 deck[:5]
#
# /usr/lib/python3.12/random.py in shuffle(self, x)
#     355             # pick an element in x[:i+1] with which to exchange x[i]
#     356             j = randbelow(i + 1)
# --> 357             x[i], x[j] = x[j], x[i]
#     358
#     359     def sample(self, population, k, *, counts=None):
#
# TypeError: 'FrenchDeck' object does not support item assignment

# %%
from collections.abc import MutableSequence
import collections

Card = collections.namedtuple('Card', ['rank', 'suit'])

class FrenchDeck2(MutableSequence):
    ranks = [str(n) for n in range(2, 11)] + list('JQKA')
    suits = 'spades diamonds clubs hearts'.split()

    def __init__(self):
        self._cards = [Card(rank, suit) for suit in self.suits
                                       for rank in self.ranks]

    def __len__(self):
        return len(self._cards)

    def __getitem__(self, position):
        return self._cards[position]

    def __setitem__(self, position, value):
        self._cards[position] = value

    def __delitem__(self, position):
        del self._cards[position]

    def insert(self, position, value):
        self._cards.insert(position, value)

# %%
import abc

class Tombola(abc.ABC):

    @abc.abstractmethod
    def load(self, iterable):
        pass

    @abc.abstractmethod
    def pick(self):
        pass

    def loaded(self):
        return bool(self.inspect())

    def inspect(self):
        items = []
        while True:
            try:
                items.append(self.pick())
            except LookupError:
                break
        self.load(items)
        return tuple(sorted(items))

# %%
import random
from tombola import Tombola

class LotteryBlower(Tombola):

    def __init__(self, iterable):
        self._balls = list(iterable)

    def load(self, iterable):
        self._balls.extend(iterable)

    def pick(self):
        try:
            position = random.randrange(len(self._balls))
        except ValueError:
            raise LookupError('pick from empty BingoCage')
        return self._balls.pop(position)

    def loaded(self):
        return bool(self._balls)

    def inspect(self):
        return tuple(sorted(self._balls))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1695747802.py in <cell line: 0>()
#       1 import random
# ----> 2 from tombola import Tombola
#       3
#       4 class LotteryBlower(Tombola):
#       5
#
# ModuleNotFoundError: No module named 'tombola'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
